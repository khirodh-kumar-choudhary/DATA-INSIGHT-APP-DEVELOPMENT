# %%
DATA = {
    210101130001 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"PAID", 5:"DAY SCHOLAR", 6:"14 CREDITS COMPLETED", 7:"9.57 CGPA", 8:"0"},
    210101130002 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"PAID", 5:"DAY SCHOLAR", 6:"14 CREDITS COMPLETED", 7:"9.57 CGPA", 8:"0"},
    210101130003 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:" ? CGPA", 8:"0"},
    210101130004 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"15 CREDITS COMPLETED", 7:"8.06 CGPA", 8:"0"},
    210101130005 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"6.68 CGPA", 8:"0"},
    210101130006 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"8.73 CGPA", 8:"0"},
    210101130007 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"7.63 CGPA", 8:"0"},
    210101130008 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"8.47 CGPA", 8:"0"},
    210101130009 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"7.05 CGPA", 8:"0"},
    210101130010 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"8.0 CGPA", 8:"0"},
    210101130011 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"7.31 CGPA", 8:"0"},
    210101130012 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"6.31 CGPA", 8:"0"},
    210101130013 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"7.47 CGPA", 8:"0"},
    210101130014 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"7.78 CGPA", 8:"0"},
    210101130015 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"6.63 CGPA", 8:"0"},
    210101130016 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"DAY SCHOLAR", 6:"16 CREDITS COMPLETED", 7:"7.42 CGPA", 8:"0"},
    210101130017 : {'DROP OUT'},
    210101130018 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"0.0 CGPA", 8:"6 BACKLOGS"},
    210101130019 : {1:"2021", 2:"ELECTRONICS AND COMMUNICATION ENGINEERING", 3:"2ND SEMESTER", 4:"NOT PAID", 5:"HOSTELLER", 6:"16 CREDITS COMPLETED", 7:"6.94 CGPA", 8:"0"},
}

# %%
from tkinter import *
root = Tk()
root.title("CHATBOT FOR STUDENT QUERY")


BG_GRAY = "#ABB2B9"
BG_COLOR = "#17202A"
TEXT_COLOR = "#EAECEE"
FONT = "Helvetica 14"
FONT_BOLD = "Helvetica 13 bold"

def send():
    send = "STUDENT -> "+e.get()
    txt.insert(END, " "+send)
    user = e.get().lower()
    if (user == "hi" or user == "hii" or user == "hello" or user == "hlo"):
        txt.insert(END,"\n" + "BOT-> HI STUDENT! ENTER YOUR REGN.NO: \n")
    elif(user == "210101130014" or user == "210101130001"):
        txt.insert(END, "\n" + "BOT -> HI STUDENT \nCHOOSE ONE OPTION FROM BELOW LIST\n------------------------------------ \n\t1: ADMISSION YEAR \n\t2: BRANCH \n\t3: CURRENT SEMESTER \n\t4: FEES PAID OR NOT \n\t5: HOSTELLER OR NOT \n\t6: NO.OF CREDITS COMPLETED \n\t7: SEMESTER WISE CGPA \n\t8: NO.OF BACKLOGS\n")
    elif(user == "1"):
        txt.insert(END,"\n"+"BOT-> 2021\n")
    elif(user == "2"):
        txt.insert(END,"\n"+"BOT-> ELECTRONICS AND COMMUNICATION ENGINEERING\n")
    elif(user == "3"):
        txt.insert(END,"\n"+"BOT-> 2ND SEMESTER\n")
    elif(user == "4"):
        txt.insert(END,"\n"+"BOT-> NOT PAID\n")
    elif(user == "5"):
        txt.insert(END,"\n"+"BOT-> DAY SCHOLAR\n")
    elif(user == "6"):
        txt.insert(END,"\n"+"BOT-> 16 CREDITS COMPLETED\n")
    elif(user == "7"):
        txt.insert(END,"\n"+"BOT-> 7.47 CGPA\n")
    elif(user == "8"):
        txt.insert(END,"\n"+"BOT-> 0 BACKLOGS\n")
    else:
        txt.insert(END, "\n" + "BOT -> ENTER A CORRECT NUMBER\n")
    e.delete(0, END)
lable1 = Label(root, bg=BG_COLOR, fg=TEXT_COLOR, text="Welcome", font=FONT_BOLD, pady=10, width=20, height=1).grid(
    row=0)
 
txt = Text(root, bg=BG_COLOR, fg=TEXT_COLOR, font=FONT, width=60)
txt.grid(row=1, column=0, columnspan=2)
 
scrollbar = Scrollbar(txt)
scrollbar.place(relheight=1, relx=0.974)
 
e = Entry(root, bg="#2C3E50", fg=TEXT_COLOR, font=FONT, width=55)
e.grid(row=2, column=0)
 
send = Button(root, text="Send", font=FONT_BOLD, bg=BG_GRAY,
              command=send).grid(row=2, column=1)
 
root.mainloop()
